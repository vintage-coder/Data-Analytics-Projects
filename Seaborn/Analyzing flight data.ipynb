# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
flight_data1=sns.load_dataset("\\Datasets\\CSV\\flights")

print(flight_data1.head())
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_data = pd.read_csv('C:\\Users\\linkeddots\\Desktop\\GTIHUB\\Data-Analytics-Projects\\Datasets\\CSV\\flights.csv')
print(flights_data.head(20))
sns.scatterplot(data=flights_data,x="year",y="passengers")
# Out:
#     year      month  passengers
# 0   1949    January         112
# 1   1949   February         118
# 2   1949      March         132
# 3   1949      April         129
# 4   1949        May         121
# 5   1949       June         135
# 6   1949       July         148
# 7   1949     August         148
# 8   1949  September         136
# 9   1949    October         119
# 10  1949   November         104
# 11  1949   December         118
# 12  1950    January         115
# 13  1950   February         126
# 14  1950      March         141
# 15  1950      April         135
# 16  1950        May         125
# 17  1950       June         149
# 18  1950       July         170
# 19  1950     August         170
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights_data,x="year",y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.barplot(data=flights_data,x="year",y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
print(flights_data.columns)

flights_data.describe()
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
sns.set(style="whitegrid")

# %%
ax=sns.swarmplot(data=flights_data,x="year",y="passengers")

# %%
plt.subplot(1,2,1)
sns.lineplot(data=flights_data,x="year",y="passengers")

plt.subplot(1,2,2)
sns.lineplot(data=flights_data,x="year",y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>
